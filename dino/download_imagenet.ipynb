# %%
from torchvision import datasets, transforms
from torchvision.datasets import ImageNet
import os

# Set the root directory where you want to store the dataset
root = './data/imagenet'

# Create the directory if it doesn't exist
os.makedirs(root, exist_ok=True)

# Define the transformations
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Download and load the ImageNet dataset
# Note: This will download the dataset if it's not already present
train_dataset = ImageNet(root=root, split='train', download=True, transform=transform)

# Print some information about the dataset
print(f"Dataset size: {len(train_dataset)}")
print(f"Number of classes: {len(train_dataset.classes)}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 21
#      12 transform = transforms.Compose([
#      13     transforms.Resize(256),
#      14     transforms.CenterCrop(224),
#      15     transforms.ToTensor(),
#      16     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
#      17 ])
#      19 # Download and load the ImageNet dataset
#      20 # Note: This will download the dataset if it's not already present
# ---> 21 train_dataset = ImageNet(root=root, split='train', download=True, transform=transform)
#      23 # Print some information about the dataset
#      24 print(f"Dataset size: {len(train_dataset)}")
#
# File ~/miniconda3/envs/sam2/lib/python3.10/site-packages/torchvision/datasets/imagenet.py:53, in ImageNet.__init__(self, root, split, **kwargs)
#      50 root = self.root = os.path.expanduser(root)
#      51 self.split = verify_str_arg(split, "split", ("train", "val"))
# ---> 53 self.parse_archives()
#      54 wnid_to_classes = load_meta_file(self.root)[0]
#      56 super().__init__(self.split_folder, **kwargs)
#
# File ~/miniconda3/envs/sam2/lib/python3.10/site-packages/torchvision/datasets/imagenet.py:66, in ImageNet.parse_archives(self)
#      64 def parse_archives(self) -> None:
#      65     if not check_integrity(os.path.join(self.root, META_FILE)):
# ---> 66         parse_devkit_archive(self.root)
#      68     if not os.path.isdir(self.split_folder):
#      69         if self.split == "train":
#
# File ~/miniconda3/envs/sam2/lib/python3.10/site-packages/torchvision/datasets/imagenet.py:147, in parse_devkit_archive(root, file)
#     144     file = archive_meta[0]
#     145 md5 = archive_meta[1]
# --> 147 _verify_archive(root, file, md5)
#     149 with get_tmp_dir() as tmp_dir:
#     150     extract_archive(os.path.join(root, file), tmp_dir)
#
# File ~/miniconda3/envs/sam2/lib/python3.10/site-packages/torchvision/datasets/imagenet.py:103, in _verify_archive(root, file, md5)
#      98 if not check_integrity(os.path.join(root, file), md5):
#      99     msg = (
#     100         "The archive {} is not present in the root directory or is corrupted. "
#     101         "You need to download it externally and place it in {}."
#     102     )
# --> 103     raise RuntimeError(msg.format(file, root))
#
# RuntimeError: The archive ILSVRC2012_devkit_t12.tar.gz is not present in the root directory or is corrupted. You need to download it externally and place it in ./data/imagenet.
